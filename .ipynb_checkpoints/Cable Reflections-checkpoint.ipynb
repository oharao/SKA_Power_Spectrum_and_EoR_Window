# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import h5py

# %%
def S_21(freq):
    return y_0 + A*np.sin(omega*freq + phi)*np.exp(-beta*freq)+np.exp(-alpha*(freq+x_0))

# %%
min = 0.072 #MHz
max = 0.108975 #MHz
channels = 1480
frequencies = np.linspace(min, max, channels)

# %%
# Initalise variables for 7m Coax Cable 
y_0 = 0.917
A = 0.007428
omega = 428
phi = 7.866
alpha = 1.844
x_0 = 1.503
beta = 0.1759;

results_7m = S_21(frequencies)

# %%
# Initalise variables for 10m Coax Cable 
y_0 = 0.8922
A = -0.00734
omega = 612.1
phi = -7.827
alpha = 1.945
x_0 = 1.281
beta = 0.2909

results_10m = S_21(frequencies)

# %%
# Initalise variables for 12m Coax Cable 
y_0 = 0.8738
A = 0.007201
omega = 735.5
phi = 1.605
alpha = 1.979
x_0 = 1.175
beta = 0.3455

results_12m = S_21(frequencies)

# %%
# Initalise variables for 12m Coax Cable 
y_0 = 0.8738
A = 0.007201
omega = 7350.5
phi = 1.605
alpha = 1.979
x_0 = 1.175
beta = 0.3455

results_example = S_21(frequencies)

# %%
plt.plot(frequencies, results_10m, label='10m')
plt.plot(frequencies, results_example, label='example')
plt.title('The effect of cable reflections on the $S_{21}$ response')
plt.ylabel('$S_{21}$')
plt.xlabel('Frequency (GHz)')
plt.legend()
plt.show()

# %%
data = np.column_stack([frequencies, results_example])
datafile_path = "example_S21_parameter.txt"
np.savetxt(datafile_path , data, fmt=['%f','%f'])
# here the ascii file is written.

# %%
# Convert from GHz to Hz.
freqs = frequencies * 1e9

# Convert gains to complex values.
gains = np.array(results_10m, dtype=np.complex128)

# Reshape gain array to 3D. Indexing must be (time, channel, station).
# (Note that we will need gains for all stations in the interferometer.)
gains = gains.reshape(1, len(gains), 1)

# Write HDF5 file with recognised dataset names.
with h5py.File("gain_model.h5", "w") as hdf_file:
    hdf_file.create_dataset("freq (Hz)", data=freqs)
    hdf_file.create_dataset("gain_xpol", data=gains)
    hdf_file.create_dataset("gain_ypol", data=gains)
